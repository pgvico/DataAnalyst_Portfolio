# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

# Primera capa
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3), kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

# Segunda capa
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu',
                           padding='same',kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu',
                           padding='same', kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

# Tercera capa
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu',
                           padding='same', kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu',
                           padding='same', kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))


model.add(ks.layers.Flatten())

model.add(ks.layers.Dense(256, activation='relu',  kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.4))
model.add(ks.layers.Dense(128, activation='relu',  kernel_initializer = 'he_uniform', kernel_regularizer = l2(0.001)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_23 (Ba  (None, 32, 32, 64)        256
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_24 (Ba  (None, 32, 32, 64)        256
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_25 (Ba  (None, 16, 16, 128)       512
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_26 (Ba  (None, 16, 16, 128)       512
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 8, 8, 128)         0
#  ng2D)
#
#  dropout_15 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_27 (Ba  (None, 8, 8, 256)         1024
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_28 (Ba  (None, 8, 8, 256)         1024
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 4, 4, 256)         0
#  ng2D)
#
#  dropout_16 (Dropout)        (None, 4, 4, 256)         0
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_8 (Dense)             (None, 256)               1048832
#
#  batch_normalization_29 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  batch_normalization_30 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 2233546 (8.52 MB)
# Trainable params: 2230986 (8.51 MB)
# Non-trainable params: 2560 (10.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 3.1 Early Stopping

# %%
# definir los callbacks de EarlyStopping
callback_loss=EarlyStopping (monitor='val_loss', patience=10)
callback_acc=EarlyStopping (monitor='val_accuracy', patience=10)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=300,
                    validation_data=(x_val_scaled, y_val), batch_size=512,
                    callbacks=[callback_loss, callback_acc])
# Out:
# Epoch 1/300
# 79/79 [==============================] - 18s 158ms/step - loss: 4.5636 - accuracy: 0.3382 - val_loss: 6.1736 - val_accuracy: 0.1128
# Epoch 2/300
# 79/79 [==============================] - 12s 149ms/step - loss: 3.7659 - accuracy: 0.4998 - val_loss: 4.5202 - val_accuracy: 0.2412
# Epoch 3/300
# 79/79 [==============================] - 12s 151ms/step - loss: 3.2396 - accuracy: 0.5843 - val_loss: 3.9651 - val_accuracy: 0.2985
# Epoch 4/300
# 79/79 [==============================] - 12s 151ms/step - loss: 2.8195 - accuracy: 0.6431 - val_loss: 3.2697 - val_accuracy: 0.4616
# Epoch 5/300
# 79/79 [==============================] - 12s 151ms/step - loss: 2.4603 - accuracy: 0.6897 - val_loss: 2.5720 - val_accuracy: 0.6001
# Epoch 6/300
# 79/79 [==============================] - 12s 151ms/step - loss: 2.1618 - accuracy: 0.7257 - val_loss: 2.3045 - val_accuracy: 0.6494
# Epoch 7/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.9159 - accuracy: 0.7519 - val_loss: 1.9537 - val_accuracy: 0.7055
# Epoch 8/300
# 79/79 [==============================] - 12s 150ms/step - loss: 1.7307 - accuracy: 0.7720 - val_loss: 1.7523 - val_accuracy: 0.7390
# Epoch 9/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.5571 - accuracy: 0.7966 - val_loss: 1.6397 - val_accuracy: 0.7510
# Epoch 10/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.4291 - accuracy: 0.8131 - val_loss: 1.5711 - val_accuracy: 0.7512
# Epoch 11/300
# 79/79 [==============================] - 12s 150ms/step - loss: 1.3397 - accuracy: 0.8265 - val_loss: 1.4795 - val_accuracy: 0.7758
# Epoch 12/300
# 79/79 [==============================] - 12s 150ms/step - loss: 1.2587 - accuracy: 0.8395 - val_loss: 1.5914 - val_accuracy: 0.7350
# Epoch 13/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.2381 - accuracy: 0.8406 - val_loss: 1.3372 - val_accuracy: 0.8080
# Epoch 14/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.1678 - accuracy: 0.8585 - val_loss: 1.4142 - val_accuracy: 0.7761
# Epoch 15/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.1507 - accuracy: 0.8626 - val_loss: 1.2895 - val_accuracy: 0.8119
# Epoch 16/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.1347 - accuracy: 0.8665 - val_loss: 1.2329 - val_accuracy: 0.8310
# Epoch 17/300
# 79/79 [==============================] - 12s 152ms/step - loss: 1.0834 - accuracy: 0.8792 - val_loss: 1.2778 - val_accuracy: 0.8170
# Epoch 18/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.0713 - accuracy: 0.8833 - val_loss: 1.3500 - val_accuracy: 0.7987
# Epoch 19/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.0877 - accuracy: 0.8808 - val_loss: 1.2598 - val_accuracy: 0.8262
# Epoch 20/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.0564 - accuracy: 0.8903 - val_loss: 1.2030 - val_accuracy: 0.8412
# Epoch 21/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.0205 - accuracy: 0.8964 - val_loss: 1.2589 - val_accuracy: 0.8291
# Epoch 22/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.0287 - accuracy: 0.8964 - val_loss: 1.2228 - val_accuracy: 0.8369
# Epoch 23/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.0664 - accuracy: 0.8901 - val_loss: 1.2448 - val_accuracy: 0.8395
# Epoch 24/300
# 79/79 [==============================] - 12s 151ms/step - loss: 1.0094 - accuracy: 0.9028 - val_loss: 1.3212 - val_accuracy: 0.8116
# Epoch 25/300
# 79/79 [==============================] - 12s 152ms/step - loss: 1.0024 - accuracy: 0.9031 - val_loss: 1.1885 - val_accuracy: 0.8469
# Epoch 26/300
# 79/79 [==============================] - 12s 152ms/step - loss: 1.0009 - accuracy: 0.9051 - val_loss: 1.2637 - val_accuracy: 0.8298
# Epoch 27/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9963 - accuracy: 0.9092 - val_loss: 1.2624 - val_accuracy: 0.8297
# Epoch 28/300
# 79/79 [==============================] - 12s 152ms/step - loss: 1.0255 - accuracy: 0.9038 - val_loss: 1.2147 - val_accuracy: 0.8456
# Epoch 29/300
# 79/79 [==============================] - 12s 151ms/step - loss: 0.9850 - accuracy: 0.9135 - val_loss: 1.1866 - val_accuracy: 0.8490
# Epoch 30/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9545 - accuracy: 0.9167 - val_loss: 1.2305 - val_accuracy: 0.8341
# Epoch 31/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9671 - accuracy: 0.9130 - val_loss: 1.3500 - val_accuracy: 0.8083
# Epoch 32/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9553 - accuracy: 0.9170 - val_loss: 1.2161 - val_accuracy: 0.8415
# Epoch 33/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9669 - accuracy: 0.9147 - val_loss: 1.1924 - val_accuracy: 0.8503
# Epoch 34/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9622 - accuracy: 0.9149 - val_loss: 1.1777 - val_accuracy: 0.8500
# Epoch 35/300
# 79/79 [==============================] - 12s 151ms/step - loss: 0.9365 - accuracy: 0.9215 - val_loss: 1.2603 - val_accuracy: 0.8337
# Epoch 36/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9345 - accuracy: 0.9193 - val_loss: 1.2145 - val_accuracy: 0.8421
# Epoch 37/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9335 - accuracy: 0.9202 - val_loss: 1.1873 - val_accuracy: 0.8481
# Epoch 38/300
# 79/79 [==============================] - 12s 152ms/step - loss: 0.9431 - accuracy: 0.9167 - val_loss: 1.2394 - val_accuracy: 0.8408

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:07:41.271300

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 83.080

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Colab Notebooks/Entregable 4/Modelos (1)"

model.save(ruta_googledrive+'cifar10_1_model.h5')
